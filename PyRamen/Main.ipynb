# %%
""" 
Homework: PyRamen

This script is used to analyze how well your business did on a per-product basis.

"""

# Import libraries

import csv
from pathlib import Path

# Set file paths for menu_data.csv and sales_data.csv

menu_filepath = Path("./02-Python_Homework_Instructions_PyRamen_Resources_menu_data.csv")
sales_filepath = Path("./02-Python_Homework_Instructions_PyRamen_Resources_sales_data.csv")

# Initialize list objects to hold our menu and sales data

menu = []
sales = []

# Read in the menu data into the menu list

with open(menu_filepath, 'r') as csvfile:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile, delimiter=',')

    # Read the header row first
    csv_header = next(csvreader)

    # Read each row of data after the header
    for row in csvreader: 
        menu.append(row)
       
    
# Read in the sales data into the sales list

with open(sales_filepath, 'r') as csvfile:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile, delimiter=',')

    # Read the header row first
    csv_header = next(csvreader)

    # Read each row of data after the header
    for row in csvreader: 
        sales.append(row)
        
report={}

for row in sales:
    # define items
    quantity = int(row[3])
    sales_item = row[4]
    # check each item against keys in report
    if sales_item not in report.keys():
        # if the value is not in the report, add it as new entry with metrics
        report[sales_item] = {
            "01-count": 0,
            "02-revenue": 0,
            "03-cogs": 0,
            "04-profit": 0 
            }
    for record in menu:
        item=record[0]
        price=float(record[3])
        cost=float(record[4])
        profit = price - cost
        if sales_item == item:
            report[sales_item]["01-count"] += quantity
            report[sales_item]["02-revenue"] += price * quantity
            report[sales_item]["03-cogs"] += cost * quantity
            report[sales_item]["04-profit"] += profit * quantity
        else:
            print(f"{name} does not equal {item}! NO MATCH!")
                    
f = open('PyRamen.txt', 'w')

# Open a file with access mode 'a'
with open("PyRamen.txt", "a") as file_object:
    file_object.write(str(report))
